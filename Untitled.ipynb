# %%
import pandas as pd

# %%
df = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    MA_HANG                                           TEN_HANG  CHAPTER  \
# 0  3061711  Tôm sú bỏ đầu lột vỏ bỏ đuôi (PD) tươi đông lạ...        3
# 1  3061711  Tôm sú tươi bỏ đầu còn đuôi đông lạnh (1.8 Kg/...        3
# 2  3061711  R_PTO 16/20(TSHRIMP16/20(1)0.9) Tôm sú tươi lộ...        3
# 3  3061711  Tôm sú bỏ đầu (HLSO) tươi đông lạnh cở 6/8 (1....        3
# 4  3061711  Tôm sú HOSO tươi đông lạnh. Size U/15 ; Packin...        3
#
#    HEADING  SUB_HEADING  COUNTRY_EXTENSION
# 0        6           17                 11
# 1        6           17                 11
# 2        6           17                 11
# 3        6           17                 11
# 4        6           17                 11

# %%
temp = df.sample(20)[['MA_HANG', "TEN_HANG"]]

# %%
temp
# Out:
#          MA_HANG                                           TEN_HANG
# 125057  30063090  2. Hóa chất chuẩn đoán Invitro  ARC TACROLIMUS...
# 28882   62046300  Quần tây nữ Ladies 70% Cotton 28% Polyester 2%...
# 175063  40169390  SPB141243 Ron - phốt bạc đạn chịu lực SR-3304 ...
# 55413   62045300                                      729512 Váy VN
# 70581   85443014  D5BC6E Bộ dây điện dùng cho Xe hơi 82161-11421...
# 106225  30064010  Xi măng hàn răng Empress Direct Refill 1x3g Op...
# 164128  38112190  Phụ gia pha chế dầu nhờn Viscoplex 1 - 330 (17...
# 66484   85177021  GH82-19978A BẢN MẠCH CHÍNH CỦA ĐIỆN THOẠI DI Đ...
# 182604  40169390  SWYASFH0015 Miếng đệm cao su dùng sản xuất mạc...
# 125735  30063090  Hóa chất chuẩn đoán Invitro: Fe-PI.LOT:60389Y6...
# 103981  30023000  Vaccine thú y SUIVAC APP emulsion for injectio...
# 53692   62033100  V2358-2 Áo vest nam ( vải chính 50% wool 48% p...
# 171054  38089330  Thuốc điều hòa sinh trưởng: SAIGON P1 15WP: Lo...
# ...

# %%
temp.to_csv("sample.csv", index=False)
